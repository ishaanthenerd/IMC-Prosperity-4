# %%
from updated_tools import *

df = extract_data(1, 20000)
df = df[(df['bid_price_1'].notna()) & (df['ask_price_1'].notna())]
df = df[df["product"] == "INTARIAN_PEPPER_ROOT"]
plot_mid_price(df, False, False, True, True)

# observation: mid_price = 12000 + (timestamp / 1e6) * 1e3
